# %% [markdown]
# ## **Ex2.2->** The company uses a vehicle with C = 50 but goods are not stored in node 1.Precisely, the company maylocate a warehouse in one of the following nodes: {2,15,20}.

# %%
import gurobipy as gb
import networkx as nx
import matplotlib.pyplot as plt
import os


#
# Drawing 
# functions
#


def DrawInitG(G, withedges=False):
    
    plt.figure(figsize=args.figsize)
    
    pos = {i:(G.nodes[i]['x'], G.nodes[i]['y']) for i in G.nodes()}
    
    nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_shape='o', 
                           node_size=600,
                           node_color='white',
                           edgecolors='black',
                           label=[G.nodes()])
        
    nx.draw_networkx_labels(G, pos=pos, font_color='k', font_size=8)
    
    if withedges:
        nx.draw_networkx_edges(G,pos=pos, alpha=1.0)
        labels = {(i,j):G.get_edge_data(i,j,'cost').get('cost') for i,j in G.edges()}
        nx.draw_networkx_edge_labels(G, pos=pos, edge_labels=labels)
    
    plt.axis('off')
    plt.show()
    
def DrawSol(G, x):
    
    plt.figure(figsize=args.figsize)
    
    pos = {i:(G.nodes[i]['x'], G.nodes[i]['y']) for i in G.nodes()}

    
        

    nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_shape='o', 
                           node_size=600,
                           node_color='white',
                           edgecolors='black',
                           label=[G.nodes()])
    
    
    nx.draw_networkx_labels(G, pos=pos, font_color='k', font_size=8)
    
    for u,v in G.edges():
        if x[u,v].x > 0.01 and x[u,v].x < 0.9:
            nx.draw_networkx_edges(G, pos=pos,
                                   edgelist=[(u,v)],
                                   edge_color='r')
            
            nx.draw_networkx_edge_labels(G, pos=pos,
                                         edge_labels={(u,v):'{:.2f}'.format(x[u,v].x)})
        
        if x[u,v].x > 0.9:
            nx.draw_networkx_edges(G, pos=pos,
                                   edgelist=[(u,v)],
                                   edge_color='k')
        


        
        
    
    plt.axis('off')
    plt.show()


def DrawSubtour (G, x, subtour):

    plt.figure(figsize=args.figsize)
    
    pos = {i:(G.nodes[i]['x'], G.nodes[i]['y']) for i in G.nodes()}


    nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_shape='o', 
                           node_size=600,
                           node_color='white',
                           edgecolors='black',
                           label=[G.nodes()])
    
    
    nx.draw_networkx_labels(G, pos=pos, font_color='k', font_size=8)
    
    
    nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_shape='o',
                           nodelist=subtour,
                           node_size=600,
                           node_color='white',
                           edgecolors='black',
                           label=[G.nodes()])
        
    

    nx.draw_networkx_labels(G, pos=pos, font_color='k', font_size=8)
    
    
    subtouredges = [(u,v) for u in subtour for v in subtour if u != v and G.has_edge(u,v)]
    
    for u,v in subtouredges:
        if x[u,v].x > 0.01 and x[u,v].x < 0.99:

            nx.draw_networkx_edges(G, pos=pos,\
                                   edgelist=[(u,v)],
                                   edge_color='r')

            nx.draw_networkx_edge_labels(G, pos=pos, 
                                         edge_labels={(u,v):f'[{x[u,v].x:.2f}, {x[v,u].x:.2f}]'})

            
        if x[u,v].x > 0.9:
            nx.draw_networkx_edges(G, pos=pos,\
                                   edgelist=[(u,v)],\
                                   edge_color='k')
            
    plt.axis('off')
    plt.show()
    
class args:
    filename = None
    scale = 15
    figsize = (10,10)

# %% [markdown]
# # ATSP
#
# >**Given**
# >A directed graph $G=(N,A)\;$ and a cost (length, distance) $c_{ij} > 0$ for each arc in $A$
# >
# >**Find**
# > The tour (a directed cycle that touch exactly once all $n$ nodes) of minimum cost (length, distance)
#
#
# ### Formulation
#
# Decision variables:
# $$
# x_{ij} = \begin{cases}1 \text{ if arc $(i, j)$ is in the tour} \\
# 0 \text{ otherwise}
# \end{cases}
# $$
#
# Formulation:
# $$
# \begin{alignat}{3}
# & \min \sum_{(i,j) \in A} c_{ij} x_{ij} &\\
# \text{s.t.} \;\;\;\;\;&\\
# \sum_{j \in \delta^+(i)} x_{ij} &= 1 \;\; \forall i \in N \;\; \text{(FS)}\\
# \sum_{j \in \delta^-(i)} x_{ji} &= 1 \;\; \forall i \in N \;\; \text{(RS)}\\
# \sum_{(i,j) \in A(S)} x_{ij} &\le |S| - 1 \;\; \forall S \subset N, |S| \ge 2 \;\; \text{(SEC)}\\
# x & \in \{0,1\}^{|A|}
# \end{alignat}
# $$

# %%
# Read the graph in the graphML format

args.filename = 'atsp18062019.gml'
args.figsize =  (20,30)

basename = os.path.splitext(args.filename)[0]

G = nx.read_graphml (args.filename, node_type=int)

print ("G has", G.number_of_nodes(), "nodes and", G.number_of_edges(), "edges")

print(G.is_directed())

root = 1
# Out:
# G has 28 nodes and 756 edges
# True

# %% [markdown]
# # ATSP: Branch-and-cut

# %% [markdown]
# SEC separation embedded into Lazy Callback
# - $ \sum_{i \in S, j \in \bar S} x_{ij} \ge 1 \;\; \forall S, 2 \le |S| \le |N|-1 $

# %%
def subtourseparation (G, x):
   
    for i,j in G.edges():
        G[i][j]['capacity'] = x[i,j].x
        
    for i in list(G.nodes())[1:]:
        cut_val, cut = nx.minimum_cut(G,1,i)
        
        if cut_val < 0.99999:
            print ('Found violated subtour inequality')
            
            if len(cut[0]) < len(cut[1]):
                subtour = (list(cut[0]))
            else:
                subtour = (list(cut[1]))
            print (subtour)
            return subtour
        
    return None

# The separation routine is transformed into a callback
def SEC_lazy_callback (model, where):

        
    if where == gb.GRB.Callback.MIPSOL:
        
        x = model._vars
        xrel = model.cbGetSolution(x)
        G = model._graph
                
        for i,j in G.edges():
            G[i][j]['capacity'] = xrel[i,j]
        
        for i in list(G.nodes())[1:]:
            cut_val, cut = nx.minimum_cut(G,1,i)
        
            if cut_val < 0.99999:
                if len(cut[0]) < len(cut[1]):
                    subtour = (list(cut[0]))
                else:
                    subtour = (list(cut[1]))
        
                
                subtouredges = [(u,v) for u in subtour for v in subtour if u != v and G.has_edge(u,v)]
                
                #print (subtour, sum( xrel[i,j] for i,j in subtouredges))
                
                model.cbLazy(gb.quicksum(x[i,j] for i,j in subtouredges) <= len(subtour) - 1)
                break

# %%
solutions = []
wharehouses = [2,15,20]

# we solve the problem one time for each wharehouse
for i in wharehouses:
    atsp_sec = gb.Model()

    x = atsp_sec.addVars(G.edges(),
                         obj=[G[i][j]['dist'] for i,j in G.edges()],
                         vtype=gb.GRB.BINARY, name='x')

    atsp_sec.write('atsp_sec.lp')

    # FS constraints
    atsp_sec.addConstrs((x.sum(i,'*') == 1 for i in G.nodes()), name='FS')
    # RS constraints
    atsp_sec.addConstrs((x.sum('*',i) == 1 for i in G.nodes()), name='RS')
    # SEC with |S|=2
    atsp_sec.addConstrs((x[i,j] + x[j,i] <= 1 for i,j in G.edges() if j > i), name='SUB2')

    # fix the node number i form the list of possible wharehouses to be the first visited
    x[root,i].lb=1
    x[root,i].ub=1

    atsp_sec.update()
    atsp_sec.write('atsp.lp')

    # Graph G and variables x are made available to Gurobi model
    atsp_sec._graph = G
    atsp_sec._vars = x

    atsp_sec.reset()
    atsp_sec.Params.lazyConstraints = 1
    atsp_sec.optimize(SEC_lazy_callback)
    
    solutions.append(atsp_sec.objVal)
# Out:
# Academic license - for non-commercial use only - expires 2021-07-16
# Using license file /home/leonardo/gurobi.lic
# Discarded solution information
# Changed value of parameter lazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 434 rows, 756 columns and 2268 nonzeros
# Model fingerprint: 0x08742dc8
# Variable types: 0 continuous, 756 integer (756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 42067.000000
# Presolve removed 55 rows and 54 columns
# Presolve time: 0.01s
# Presolved: 379 rows, 702 columns, 2054 nonzeros
# Variable types: 0 continuous, 702 integer (702 binary)
#
# Root relaxation: objective 1.491200e+04, 70 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 15829.5000    0   14 42067.0000 15829.5000  62.4%     -    0s
# H    0     0                    16138.000000 15829.5000  1.91%     -    0s
# H    0     0                    16128.000000 15829.5000  1.85%     -    0s
#      0     0 15854.2500    0   49 16128.0000 15854.2500  1.70%     -    0s
#      0     0 15854.2500    0   13 16128.0000 15854.2500  1.70%     -    0s
# H    0     0                    16103.000000 15854.2500  1.54%     -    0s
# H    0     0                    15877.000000 15854.2500  0.14%     -    0s
# H    0     0                    15871.000000 15854.2500  0.11%     -    0s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (202 simplex iterations) in 0.23 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 15871 15877 16103 ... 42067
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.587100000000e+04, best bound 1.587100000000e+04, gap 0.0000%
#
# User-callback calls 95, time in user-callback 0.18 sec
# Discarded solution information
# Changed value of parameter lazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 434 rows, 756 columns and 2268 nonzeros
# Model fingerprint: 0x08fefa61
# Variable types: 0 continuous, 756 integer (756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 55 rows and 54 columns
# Presolve time: 0.01s
# Presolved: 379 rows, 702 columns, 2054 nonzeros
# Variable types: 0 continuous, 702 integer (702 binary)
# Found heuristic solution: objective 47885.000000
#
# Root relaxation: objective 1.396300e+04, 65 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 14387.5000    0   20 47885.0000 14387.5000  70.0%     -    0s
# H    0     0                    41868.000000 14387.5000  65.6%     -    0s
#      0     0 14962.0000    0   26 41868.0000 14962.0000  64.3%     -    0s
#      0     0 15037.0000    0   35 41868.0000 15037.0000  64.1%     -    0s
#      0     0 15178.0000    0   20 41868.0000 15178.0000  63.7%     -    0s
# H    0     2                    18979.000000 15178.0000  20.0%     -    0s
#      0     2 15265.5000    0   14 18979.0000 15265.5000  19.6%     -    0s
# H    7    11                    17909.000000 15307.0000  14.5%   5.6    0s
# *   11    11               3    15675.000000 15372.5000  1.93%  13.2    0s
# *   24     0               5    15645.000000 15645.0000  0.00%   9.1    0s
#
# Cutting planes:
#   Zero half: 1
#   Lazy constraints: 23
#
# Explored 25 nodes (374 simplex iterations) in 0.38 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 15645 15675 17909 ... 47885
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.564500000000e+04, best bound 1.564500000000e+04, gap 0.0000%
#
# User-callback calls 220, time in user-callback 0.25 sec
# Discarded solution information
# Changed value of parameter lazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 434 rows, 756 columns and 2268 nonzeros
# Model fingerprint: 0x3791fb29
# Variable types: 0 continuous, 756 integer (756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 55 rows and 54 columns
# Presolve time: 0.01s
# Presolved: 379 rows, 702 columns, 2054 nonzeros
# Variable types: 0 continuous, 702 integer (702 binary)
#
# Root relaxation: objective 1.461400e+04, 69 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 14614.0000    0   30          - 14614.0000      -     -    0s
#      0     0 15336.0000    0   30          - 15336.0000      -     -    0s
#      0     0 15594.0000    0   20          - 15594.0000      -     -    0s
# H    0     0                    16828.000000 15594.0000  7.33%     -    0s
#      0     0 15783.2500    0   31 16828.0000 15783.2500  6.21%     -    0s
#      0     0 15783.2500    0   38 16828.0000 15783.2500  6.21%     -    0s
# H    0     0                    16652.000000 15783.2500  5.22%     -    0s
#      0     0 15855.0000    0   29 16652.0000 15855.0000  4.79%     -    0s
# H    0     0                    16544.000000 15855.0000  4.16%     -    0s
#      0     0 15863.0000    0   31 16544.0000 15863.0000  4.12%     -    0s
#      0     0 15912.5000    0   40 16544.0000 15912.5000  3.82%     -    0s
#      0     0 15912.5000    0   39 16544.0000 15912.5000  3.82%     -    0s
#      0     0 15912.5000    0   26 16544.0000 15912.5000  3.82%     -    0s
#      0     0 15912.5000    0   35 16544.0000 15912.5000  3.82%     -    0s
#      0     0 15912.5000    0   39 16544.0000 15912.5000  3.82%     -    0s
#      0     0 15952.7692    0   73 16544.0000 15952.7692  3.57%     -    0s
#      0     0 15953.0000    0   68 16544.0000 15953.0000  3.57%     -    0s
#      0     0 15974.8837    0   71 16544.0000 15974.8837  3.44%     -    0s
#      0     0 15978.9130    0   75 16544.0000 15978.9130  3.42%     -    0s
#      0     0 15979.1810    0   76 16544.0000 15979.1810  3.41%     -    0s
# H    0     0                    16444.000000 15979.1810  2.83%     -    0s
#      0     0 15979.1810    0   76 16444.0000 15979.1810  2.83%     -    0s
# H    0     0                    15997.000000 15979.1810  0.11%     -    0s
# H    0     0                    15984.000000 15979.1810  0.03%     -    0s
#      0     0 15979.1810    0   76 15984.0000 15979.1810  0.03%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   Clique: 1
#   MIR: 1
#   Zero half: 7
#   Mod-K: 1
#   RLT: 1
#   Lazy constraints: 2
#
# Explored 1 nodes (423 simplex iterations) in 0.56 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 15984 15997 16444 ... 16828
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.598400000000e+04, best bound 1.598400000000e+04, gap 0.0000%
#
# User-callback calls 290, time in user-callback 0.29 sec

# %%
for i in range(len(wharehouses)):
    print("Solution with wharehouse", wharehouses[i] , "is:", solutions[i])
# Out:
# Solution with wharehouse 2 is: 15871.0
# Solution with wharehouse 15 is: 15645.000000000004
# Solution with wharehouse 20 is: 15984.0

# %% [markdown]
# ### The best configuration is the one with a wharehouse in **node 15** and its value is 15645

# %% [markdown]
# # Strengthen formulation

# %%
# The lazy cut callback will be transformed into a cut callback
def SEC_cut_callback (model, where):

    if where == gb.GRB.Callback.MIPNODE:
        status = model.cbGet(gb.GRB.Callback.MIPNODE_STATUS)
        count = model.cbGet(gb.GRB.Callback.MIPNODE_NODCNT)
        if status == gb.GRB.OPTIMAL and count < 1:
            x = model._vars
            xrel = model.cbGetNodeRel(x) 
            G = model._graph

            for i,j in G.edges():
                G[i][j]['capacity'] = xrel[i,j]

            for i in list(G.nodes())[1:]:
                cut_val, cut = nx.minimum_cut(G,1,i)

                if cut_val < 0.99999:
                    if len(cut[0]) < len(cut[1]):
                        subtour = (list(cut[0]))
                    else:
                        subtour = (list(cut[1]))

                    subtouredges = [(u,v) for u in subtour \
                                for v in subtour if u != v and G.has_edge(u,v)]

                    model.cbCut(gb.quicksum(x[i,j] for i,j in subtouredges) <= len(subtour) - 1)

                    break

# %% [markdown]
# Miller-Tucker-Zemlin lifted formulation (Desrochers-Laporte)
# $$
# \begin{alignat}{3}
# & \min \sum_{(i,j) \in A} x_{ij} &\\
# \text{s.t.} \;\;\;\;\;&\\
# \sum_{j \in \delta^+(i)} x_{ij} &= 1 \;\; \forall i \in N \;\; \text{(FS)}\\
# \sum_{j \in \delta^-(i)} x_{ji} &= 1 \;\; \forall i \in N \;\; \text{(RS)}\\
# u_i - u_j + (n-1)x_{ij} + (n-3)x_{ji} &\le n-2 \;\; \forall (i,j) \in A, i\not=1,j\not=1 \;\; \text{(MTZ)}\\
# x & \in \{0,1\}^{|A|}\\
# u_1 &= 1\\
# 2 &\le u_i \le n \;\; \forall i \in N, i \not = \{1\}
# \end{alignat}
# $$

# %%
solutions = []
wharehouses = [2,15,20]

for i in wharehouses:
    atsp_mtz = gb.Model()

    x = atsp_mtz.addVars(G.edges(),\
                     obj=[G[i][j]['dist']\
                          for i,j in G.edges()],\
                 vtype=gb.GRB.BINARY, name='x')

    u = atsp_mtz.addVars(G.nodes(), obj=[0.0 for i in G.nodes()],\
                         lb=2.0, ub=G.number_of_nodes(), vtype=gb.GRB.CONTINUOUS,\
                        name='u')

    atsp_sec.update()
    atsp_sec.write('atsp.lp')

    # FS constraints
    atsp_mtz.addConstrs((x.sum(i,'*') == 1 for i in G.nodes()), name='FS')
    # RS constraints
    atsp_mtz.addConstrs((x.sum('*',i) == 1 for i in G.nodes()), name='RS')
    # SEC with |S|=2
    atsp_mtz.addConstrs((x[i,j] + x[j,i] <= 1 for i,j in G.edges() if j > i), name='SUB2')

    # fix the node number i form the list of possible wharehouses to be the first visited
    x[root,i].lb=1
    x[root,i].ub=1

    atsp_mtz.addConstrs((u[i] - u[j] + (G.number_of_nodes() - 1) * x[i,j] + \
                       (G.number_of_nodes() - 3) * x[j,i] <= (G.number_of_nodes() - 2)\
                       for i in G.nodes()\
                        for j in G.nodes()\
                       if (i != j) and (i != 1) and (j !=1 ) and G.has_edge(i,j) and G.has_edge(j,i)), name='MTZ')

    atsp_mtz.update()
    atsp_mtz.write('atsp_mtz.lp')

    atsp_mtz._vars = x
    atsp_mtz._graph = G

    atsp_mtz.reset()
    atsp_mtz.Params.PreCrush = 1
    atsp_sec.Params.lazyConstraints = 0
    atsp_mtz.optimize(SEC_cut_callback)

    DrawSol(G,x)
    
    solutions.append(atsp_mtz.objVal)
# Out:
# Discarded solution information
# Changed value of parameter PreCrush to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Changed value of parameter lazyConstraints to 0
#    Prev: 1  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1136 rows, 784 columns and 5076 nonzeros
# Model fingerprint: 0xae289a52
# Variable types: 28 continuous, 756 integer (756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+02, 4e+03]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 55 rows and 55 columns
# Presolve time: 0.01s
# Presolved: 1081 rows, 729 columns, 4810 nonzeros
# Variable types: 27 continuous, 702 integer (702 binary)
# Found heuristic solution: objective 47075.000000
#
# Root relaxation: objective 1.492914e+04, 112 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 14929.1362    0   34 47075.0000 14929.1362  68.3%     -    0s
# H    0     0                    19959.000000 14929.1362  25.2%     -    0s
# H    0     0                    19495.000000 14939.0731  23.4%     -    0s
#      0     0 14981.7493    0   44 19495.0000 14981.7493  23.2%     -    0s
# H    0     0                    19411.000000 15067.5278  22.4%     -    0s
# H    0     0                    18755.000000 15067.5278  19.7%     -    0s
#      0     0 15127.7508    0   51 18755.0000 15127.7508  19.3%     -    0s
#      0     0 15140.9666    0   63 18755.0000 15140.9666  19.3%     -    0s
#      0     0 15149.9675    0   42 18755.0000 15149.9675  19.2%     -    0s
#      0     0 15331.6222    0   17 18755.0000 15331.6222  18.3%     -    0s
#      0     0 15493.4000    0   11 18755.0000 15493.4000  17.4%     -    0s
#      0     0 15517.8710    0   22 18755.0000 15517.8710  17.3%     -    0s
# H    0     0                    16199.000000 15517.8710  4.20%     -    0s
#      0     0 15829.5000    0   14 16199.0000 15829.5000  2.28%     -    0s
#      0     0 15829.5000    0   14 16199.0000 15829.5000  2.28%     -    0s
#      0     0 15870.5000    0    8 16199.0000 15870.5000  2.03%     -    0s
#      0     0 15870.5000    0   24 16199.0000 15870.5000  2.03%     -    0s
#      0     0 15870.5000    0    9 16199.0000 15870.5000  2.03%     -    0s
# H    0     0                    16050.000000 15870.5000  1.12%     -    0s
#      0     0 15870.5000    0   44 16050.0000 15870.5000  1.12%     -    0s
#      0     0 15870.5000    0    8 16050.0000 15870.5000  1.12%     -    0s
#      0     0 15870.5000    0    8 16050.0000 15870.5000  1.12%     -    0s
# *    0     0               0    15871.000000 15871.0000  0.00%     -    0s
#
# Cutting planes:
#   User: 8
#   Gomory: 4
#   Implied bound: 2
#   MIR: 2
#   Zero half: 3
#   Relax-and-lift: 2
#
# Explored 1 nodes (564 simplex iterations) in 0.46 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 15871 16050 16199 ... 47075
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.587100000000e+04, best bound 1.587100000000e+04, gap 0.0000%
#
# User-callback calls 281, time in user-callback 0.22 sec
# Discarded solution information
# Changed value of parameter PreCrush to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Parameter lazyConstraints unchanged
#    Value: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1136 rows, 784 columns and 5076 nonzeros
# Model fingerprint: 0xbffd0f8e
# Variable types: 28 continuous, 756 integer (756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+02, 4e+03]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 55 rows and 55 columns
# Presolve time: 0.02s
# Presolved: 1081 rows, 729 columns, 4810 nonzeros
# Variable types: 27 continuous, 702 integer (702 binary)
# Found heuristic solution: objective 47885.000000
#
# Root relaxation: objective 1.399249e+04, 109 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 13992.4892    0   51 47885.0000 13992.4892  70.8%     -    0s
# H    0     0                    17198.000000 13992.4892  18.6%     -    0s
#      0     0 14443.8678    0   55 17198.0000 14443.8678  16.0%     -    0s
# H    0     0                    16788.000000 14443.8678  14.0%     -    0s
#      0     0 14536.8228    0   56 16788.0000 14536.8228  13.4%     -    0s
#      0     0 14541.5515    0   35 16788.0000 14541.5515  13.4%     -    0s
#      0     0 14704.4697    0   30 16788.0000 14704.4697  12.4%     -    0s
#      0     0 14717.1667    0   41 16788.0000 14717.1667  12.3%     -    0s
#      0     0 14736.9351    0   46 16788.0000 14736.9351  12.2%     -    0s
#      0     0 14749.0909    0   31 16788.0000 14749.0909  12.1%     -    0s
#      0     0 14858.0556    0   16 16788.0000 14858.0556  11.5%     -    0s
#      0     0 14870.5000    0   12 16788.0000 14870.5000  11.4%     -    0s
# H    0     0                    16226.000000 14870.5000  8.35%     -    0s
#      0     0 15094.3118    0   40 16226.0000 15094.3118  6.97%     -    0s
#      0     0 15094.3118    0   50 16226.0000 15094.3118  6.97%     -    0s
#      0     0 15094.3118    0   48 16226.0000 15094.3118  6.97%     -    0s
#      0     0 15117.3328    0   18 16226.0000 15117.3328  6.83%     -    0s
#      0     0 15144.7205    0   13 16226.0000 15144.7205  6.66%     -    0s
# H    0     0                    16220.000000 15144.7205  6.63%     -    0s
#      0     0 15356.0321    0    9 16220.0000 15356.0321  5.33%     -    0s
#      0     0 15559.2500    0   40 16220.0000 15559.2500  4.07%     -    0s
#      0     0 15559.2500    0   40 16220.0000 15559.2500  4.07%     -    0s
#      0     0 15632.8750    0   59 16220.0000 15632.8750  3.62%     -    0s
#      0     0 15632.8750    0   49 16220.0000 15632.8750  3.62%     -    0s
#      0     0 15632.8750    0   31 16220.0000 15632.8750  3.62%     -    0s
#      0     0 15632.8750    0   41 16220.0000 15632.8750  3.62%     -    0s
#      0     0 15632.8750    0   58 16220.0000 15632.8750  3.62%     -    0s
#      0     0 15632.8750    0   58 16220.0000 15632.8750  3.62%     -    0s
#      0     0 15644.5000    0    8 16220.0000 15644.5000  3.55%     -    0s
# *    0     0               0    15645.000000 15645.0000  0.00%     -    0s
#
# Cutting planes:
#   User: 10
#   Implied bound: 3
#   MIR: 4
#   Zero half: 9
#   Relax-and-lift: 2
#
# Explored 1 nodes (992 simplex iterations) in 0.79 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 15645 16220 16226 ... 47885
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.564500000000e+04, best bound 1.564500000000e+04, gap 0.0000%
#
# User-callback calls 412, time in user-callback 0.36 sec
# Discarded solution information
# Changed value of parameter PreCrush to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Parameter lazyConstraints unchanged
#    Value: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1136 rows, 784 columns and 5076 nonzeros
# Model fingerprint: 0xeddd137d
# Variable types: 28 continuous, 756 integer (756 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+02, 4e+03]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 55 rows and 55 columns
# Presolve time: 0.01s
# Presolved: 1081 rows, 729 columns, 4810 nonzeros
# Variable types: 27 continuous, 702 integer (702 binary)
# Found heuristic solution: objective 49189.000000
# Found heuristic solution: objective 46077.000000
#
# Root relaxation: objective 1.462756e+04, 114 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 14627.5556    0   40 46077.0000 14627.5556  68.3%     -    0s
# H    0     0                    20155.000000 14627.5556  27.4%     -    0s
# H    0     0                    16958.000000 14656.5556  13.6%     -    0s
#      0     0 14750.8333    0   24 16958.0000 14750.8333  13.0%     -    0s
#      0     0 15188.8586    0   51 16958.0000 15188.8586  10.4%     -    0s
#      0     0 15276.7593    0   56 16958.0000 15276.7593  9.91%     -    0s
#      0     0 15351.1182    0   39 16958.0000 15351.1182  9.48%     -    0s
#      0     0 15535.0000    0   37 16958.0000 15535.0000  8.39%     -    0s
#      0     0 15746.6667    0   36 16958.0000 15746.6667  7.14%     -    0s
#      0     0 15746.6667    0   45 16958.0000 15746.6667  7.14%     -    0s
#      0     0 15746.6667    0   34 16958.0000 15746.6667  7.14%     -    0s
#      0     0 15746.6667    0   36 16958.0000 15746.6667  7.14%     -    0s
#      0     0 15752.0000    0   38 16958.0000 15752.0000  7.11%     -    0s
#      0     0 15771.0000    0    6 16958.0000 15771.0000  7.00%     -    0s
#      0     0 15786.0000    0   36 16958.0000 15786.0000  6.91%     -    0s
#      0     0 15801.8750    0   58 16958.0000 15801.8750  6.82%     -    0s
#      0     0 15802.0000    0   37 16958.0000 15802.0000  6.82%     -    0s
#      0     0 15845.7500    0   36 16958.0000 15845.7500  6.56%     -    0s
# H    0     0                    16444.000000 15845.7500  3.64%     -    0s
#      0     0 15845.7500    0   36 16444.0000 15845.7500  3.64%     -    0s
#      0     0 15846.6667    0   59 16444.0000 15846.6667  3.63%     -    0s
#      0     0 15846.6667    0   42 16444.0000 15846.6667  3.63%     -    0s
#      0     0 15846.6667    0   33 16444.0000 15846.6667  3.63%     -    0s
#      0     0 15846.6667    0   14 16444.0000 15846.6667  3.63%     -    0s
#      0     0 15846.6667    0   60 16444.0000 15846.6667  3.63%     -    0s
#      0     0 15846.6667    0   37 16444.0000 15846.6667  3.63%     -    0s
#      0     0 15846.6667    0   63 16444.0000 15846.6667  3.63%     -    0s
#      0     0 15851.8571    0   64 16444.0000 15851.8571  3.60%     -    0s
#      0     0 15851.8571    0   64 16444.0000 15851.8571  3.60%     -    0s
#      0     0 15858.6667    0   20 16444.0000 15858.6667  3.56%     -    1s
#      0     0 15860.0000    0   19 16444.0000 15860.0000  3.55%     -    1s
#      0     0 15860.0000    0   19 16444.0000 15860.0000  3.55%     -    1s
#      0     0 15860.0000    0   19 16444.0000 15860.0000  3.55%     -    1s
#      0     0 15860.0000    0   19 16444.0000 15860.0000  3.55%     -    1s
#      0     0 15860.0000    0   19 16444.0000 15860.0000  3.55%     -    1s
# H    0     0                    16257.000000 15860.0000  2.44%     -    1s
#      0     0 15875.0000    0   42 16257.0000 15875.0000  2.35%     -    1s
#      0     0 15875.0000    0   33 16257.0000 15875.0000  2.35%     -    1s
#      0     0 15875.0000    0   18 16257.0000 15875.0000  2.35%     -    1s
#      0     0 15875.0000    0   31 16257.0000 15875.0000  2.35%     -    1s
#      0     0 15875.0000    0   19 16257.0000 15875.0000  2.35%     -    1s
#      0     0 15875.0000    0   19 16257.0000 15875.0000  2.35%     -    1s
#      0     0 15875.0000    0   19 16257.0000 15875.0000  2.35%     -    1s
#      0     0 15875.0000    0   19 16257.0000 15875.0000  2.35%     -    1s
#      0     0 15875.0000    0   19 16257.0000 15875.0000  2.35%     -    1s
#      0     2 15875.0000    0   19 16257.0000 15875.0000  2.35%     -    1s
# H    5     6                    16106.000000 15875.0000  1.43%  22.4    1s
# H    9     4                    15998.000000 15877.0000  0.76%  16.8    1s
# *   38     0              14    15984.000000 15914.0000  0.44%  13.2    1s
#
# Cutting planes:
#   User: 8
#   Gomory: 2
#   Implied bound: 2
#   MIR: 4
#   Zero half: 11
#   RLT: 3
#   Relax-and-lift: 5
#
# Explored 44 nodes (1907 simplex iterations) in 1.83 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 15984 15998 16106 ... 49189
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.598400000000e+04, best bound 1.598400000000e+04, gap 0.0000%
#
# User-callback calls 742, time in user-callback 1.04 sec

# %%
for i in range(len(wharehouses)):
    print("Solution with wharehouse", wharehouses[i] , "is:", solutions[i])
# Out:
# Solution with wharehouse 2 is: 15871.0
# Solution with wharehouse 15 is: 15645.0
# Solution with wharehouse 20 is: 15984.0

# %% [markdown]
# - The value of the linear relaxation is:
#     - wharehouse in node 2: 1.399249e+04
#     - wharehouse in node 15: 1.399249e+04
#     - wharehouse in node 20: 1.462756e+04
# - The number of nodes explored is 1

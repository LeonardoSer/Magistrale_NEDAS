# %% [markdown]
# ## Network Optimization June 8 2021
#
# ### 274426	Serilli	Leonardo
#
# ### Exercise 1
#
# The graph ``11_net08062021.gml``  contains a set of potential customers that a telecom company can connect with a network rooted in node 1.
#
# The number of customers in each node is stored in the node attribute ``customer``.
#
# Each edge $uv$ has an activation cost \[``cost`` attribute in the graph\].
#
# #### Questions
#
# 1.	Find the set of links that connects all nodes at minimum cost.
# 2.	Find the set of links that connects at least $95\%$ of the customers at minimum cost with the constraint that each node in the network can accept up to 2 connections.
# 3.	From network 1, suppose that you can install one hub in one of the nodes \[6,11,14\] with the following features:
#     a.	If the hub is installed in node $k$, the cost of a link from node $k$ to any other node is zero;
#     b.	The hub can accept up to 6 connections.

# %%
import networkx as nx
import gurobipy as gb
import os
import matplotlib.pyplot as plt

# %%
# Drawing functions

def DrawInitG(G, withedges=False):
    
    plt.figure(figsize=args.figsize)
    
    pos = {i:(G.nodes[i]['x'], G.nodes[i]['y']) for i in G.nodes()}
    
    nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_shape='o', 
                           node_size=600,
                           node_color='red')
    
    nx.draw_networkx_labels(G, pos=pos, font_color='w', font_size=12)
    
    if withedges:
        nx.draw_networkx_edges(G,pos=pos, alpha=1.0)
        labels = {(i,j):G.get_edge_data(i,j,'cost').get('cost') for i,j in G.edges()}
        nx.draw_networkx_edge_labels(G, pos=pos, edge_labels=labels)
    
    plt.axis('off')
    plt.show()
    
def DrawSol(G, x):
    
    plt.figure(figsize=args.figsize)
    
    pos = {i:(G.nodes[i]['x'], G.nodes[i]['y']) for i in G.nodes()}

    
    nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_shape='o', 
                           node_size=600,
                           node_color='red',
                           label=[G.nodes()])
    
    nx.draw_networkx_labels(G, pos=pos, font_color='w', font_size=12)
    
    for u,v in G.edges():
        if x[u,v].x > 0.01 and x[u,v].x < 0.9:
            nx.draw_networkx_edges(G, pos=pos,
                                   edgelist=[(u,v)],
                                   edge_color='r')
            
            nx.draw_networkx_edge_labels(G, pos=pos,
                                         edge_labels={(u,v):'{:.2f}'.format(x[u,v].x)})
        
        if x[u,v].x > 0.9:
            nx.draw_networkx_edges(G, pos=pos,
                                   edgelist=[(u,v)],
                                   edge_color='k')
        

    
    #edges_in_sol = [(u,v)  for u,v in G.edges() if x[u,v].x > 0.1]

    
    plt.axis('off')
    plt.show()
    
class args:
    filename = None
    figsize = 30,60
    scale = 40

# %% [markdown]
# ## Prize Collecting Steiner Tree (PCST)
#
# ### Problem definition
#
# >**Given**
# > * A symmetric graph $G=(V,E)$ and a cost $c_e > 0$ for each edge in $E$;
# > * A root node $\{0\}$;
# > * A revenue $p_j > 0$ for each node $j \in V \setminus \{0\}$;
#
# >
# >**Find**
# >A subtree $T$ rooted in $\{0\}$ that **maximizes** the sum of the revenues of
# >the nodes in $T$ **minus** the sum of the costs of the edges in $T$
#
# ### Directed formulation
#
# Consider the bidirected graph $B=(V,A)$ that is obtained from $G$ by replacing each edge $e = \{i, j\}$ in $E$ with two directed arcs $(i, j)$ and
# $(j, i)$ (with corresponding weights $c_{ij} = c_{ji} = c_e )$ and a cost $c_e > 0$ for each edge in $E$
#
# > **PCST** is equivalent to find an optimal **arborescence** in $B$ rooted in $\{0\}$
#
#
# #### Variables
# $$
# x_{ij} = \begin{cases}1 \text{ if arc $(i, j)$ is in the arborescence} \\
# 0 \text{ otherwise}
# \end{cases}
# $$
#
# $$
# y_j = \begin{cases} 1 \text{ if node j is in the arborescence}\\
# 0 \text{ otherwise}
# \end{cases}
# $$
#
# #### Directed cut formulation
#
# $$
# \begin{align}
# \min & \sum_{(i,j) \in A} c_{ij} x_{ij} - \sum_{j \in V \setminus \{0\}} p_j y_j \\
# \text{subject}& \text{ to} \\
# y_0 & = 1 \\
# \sum_{i \in \delta^-(j)} x_{ij} & = y_j \;\; \forall j \in V\\
# \sum_{(i,j)\in \delta^+(S) x_{ij}} x_{ij}& \ge y_k \;\; \forall S \subset V, 0 \in S, k \in V\setminus S\\
# x_{ij} & \in \{0,1\} \;\; \forall(i,j) \in A \\
# y_j & \in \{0,1\} \;\; \forall j \in V
# \end{align}
# $$
#
# ### Formulation with *positional* variables (MTZ formulation)
#
# #### Variables
# $$
# x_{ij} = \begin{cases}1 \text{ if arc $(i, j)$ is in the arborescence} \\
# 0 \text{ otherwise}
# \end{cases}
# $$
#
# $$
# y_j = \begin{cases} 1 \text{ if node j is in the arborescence}\\
# 0 \text{ otherwise}
# \end{cases}
# $$
#
# $$
# u_j = \{\text{number of arcs in the dipath (if any) induced by $x$ from \{0\} to $j$}\}
# $$
#
# #### MTZ formulation
#
# $$
# \begin{align}
# \min & \sum_{(i,j) \in A} c_{ij} x_{ij} - \sum_{j \in V \setminus \{0\}} p_j y_j \\
# \text{subject}& \text{ to} \\
# y_0 & = 1 \\
# \sum_{i \in \delta^-(j)} x_{ij} & = y_j \;\; \forall j \in V\\
# (n+1)x_{ij} + u_i - u_j &\le n \;\; \forall (i,j) \in A \\
# x_{jk} &\le y_j \;\; \forall k \in \delta^+(j), \;\; \forall j \in V \setminus\{0\}\\
# 0 \le u_j & \le n \;\; \forall j \in V \\
# x_{ij} & \in \{0,1\} \;\; \forall(i,j) \in A \\
# y_j & \in \{0,1\} \;\; \forall j \in V
# \end{align}
# $$

# %% [markdown]
# ## **Ex1_Q1 ->** 1.	Find the set of links that connects all nodes at minimum cost.
# **Note** that there is no profit for adding a node to the network, so we can avoid variable $p_j$ and it's role in the objective function when we will define the model

# %%
# Read the graph in the graphML format

args.filename = '11_net08062021.gml'

basename = os.path.splitext(args.filename)[0]

G = nx.read_graphml(args.filename, node_type=int)
print ("G has", G.number_of_nodes(), "nodes and", G.number_of_edges(), "edges")

root = 1 # fix the root node

# rendiamo il grafo G diretto
D = G.to_directed()
# Out:
# G has 30 nodes and 435 edges

# %%
G.nodes(data=True)
# Out:
# NodeDataView({1: {'y': 45, 'customer': 7587, 'revenue': 170, 'x': 22}, 2: {'y': 24, 'customer': 12438, 'revenue': 745, 'x': 32}, 3: {'y': 9, 'customer': 7592, 'revenue': 826, 'x': 32}, 4: {'y': 25, 'customer': 46870, 'revenue': 458, 'x': 4}, 5: {'y': 30, 'customer': 3365, 'revenue': 300, 'x': 37}, 6: {'y': 42, 'customer': 5649, 'revenue': 290, 'x': 24}, 7: {'y': 20, 'customer': 10638, 'revenue': 626, 'x': 11}, 8: {'y': 9, 'customer': 5791
, 30, {'cost': 2865}), (6, 7, {'cost': 2555}), (6, 8, {'cost': 3313}), (6, 9, {'cost': 3920}), (6, 10, {'cost': 1581}), (6, 11, {'cost': 854}), (6, 12, {'cost': 3765}), (6, 13, {'cost': 583}), (6, 14, {'cost': 948}), (6, 15, {'cost': 2088}), (6, 16, {'cost': 1886}), (6, 17, {'cost': 2561}), (6, 18, {'cost': 1886}), (6, 19, {'cost': 4429}), (6, 20, {'cost': 3067}), (6, 21, {'cost': 1503}), (6, 22, {'cost': 1824}), (6, 23, {'cost': 1702}), (6, 24, {'cost': 1900}), (6, 25, {'cost': 4079}), (6, 26, {'cost': 806}), (6, 27, {'cost': 905}), (6, 28, {'cost': 2961}), (6, 29, {'cost': 1000}), (6, 30, {'cost': 3800}), (7, 8, {'cost': 1951}), (7, 9, {'cost': 1923}), (7, 10, {'cost': 9 ...

# %%
pcst = gb.Model()
pcst.ModelSense = gb.GRB.MAXIMIZE

# Variables definition

x = pcst.addVars(D.edges(), vtype=gb.GRB.BINARY, \
                 obj = [- D[i][j]['cost'] for i,j in D.edges()], \
                 name = 'x')

# here we avoid to set the `obj` parameter because there is no profit attribute
y = pcst.addVars (G.nodes(), vtype = gb.GRB.BINARY, \
                  name = 'y')

u = pcst.addVars (G.nodes(), vtype = gb.GRB.CONTINUOUS, 
                  lb = 0.0, ub = G.number_of_nodes(),\
                 name = 'u')

# %%
# Constraints 

# Root is in the solution
pcst.addConstr(y[root] == 1, name = 'Fix')

pcst.update()

# Each node has exactly one incoming arc

pcst.addConstrs((x.sum('*',j) == y[j] for j in G.nodes() if j != root), name='Node')

# Precedence constraints (MTZ constraints)

pcst.addConstrs(((G.number_of_nodes() +  1) * x[i,j] + u[i] - u[j] <= G.number_of_nodes() for i,j in D.edges()), name = 'MTZ')

# Connectivity constraints

pcst.addConstrs((x[j,k] <= y[j] for j in G.nodes() \
                 if j != root for k in D.neighbors(j)), name = 'Connect')
pcst.update() 
pcst.write('pcst.lp')

# %% [markdown]
# #### We must connect all nodes so we need a min customer costraint with the totality of customers
# **note** the question can also be solved by MST formulation

# %%
customers = {i:G.nodes[i]["customer"] for i in G.nodes()}
n_customers = sum([G.nodes[i]["customer"] for i in G.nodes()])

pcst.addConstr(y.prod(customers) >= n_customers, name = 'minCustomers')

pcst.update() 
pcst.write('pcst.lp')

# %%
pcst.optimize()

totalcost = 0

for i,j in D.edges():
        if x[i,j].x > 0.1:
            totalcost += D[i][j]['cost']
            
print("\n------------------------------------------------------------------------------\n")
print ("Total cost", totalcost)
print("\n------------------------------------------------------------------------------\n")

# Draw the solution 
DrawSol(D,x)
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1742 rows, 930 columns and 5193 nonzeros
# Model fingerprint: 0x255b93b8
# Variable types: 30 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+02, 5e+03]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 3e+05]
# Presolve removed 872 rows and 60 columns
# Presolve time: 0.02s
# Presolved: 870 rows, 870 columns, 3335 nonzeros
# Variable types: 29 continuous, 841 integer (841 binary)
# Found heuristic solution: objective -68861.00000
#
# Root relaxation: objective -1.447377e+04, 61 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -14473.774    0   12 -68861.000 -14473.774  79.0%     -    0s
# H    0     0                    -27144.00000 -14473.774  46.7%     -    0s
#      0     0 -15500.355    0   25 -27144.000 -15500.355  42.9%     -    0s
# H    0     0                    -26279.00000 -15500.355  41.0%     -    0s
# H    0     0                    -20819.00000 -15500.355  25.5%     -    0s
#      0     0 -15596.710    0   24 -20819.000 -15596.710  25.1%     -    0s
#      0     0 -15636.000    0   24 -20819.000 -15636.000  24.9%     -    0s
#      0     0 -15636.000    0   24 -20819.000 -15636.000  24.9%     -    0s
# H    0     0                    -20596.00000 -15636.000  24.1%     -    0s
#      0     0 -15636.000    0   24 -20596.000 -15636.000  24.1%     -    0s
# H    0     0                    -20193.00000 -15636.000  22.6%     -    0s
#      0     0 -15636.387    0   26 -20193.000 -15636.387  22.6%     -    0s
# H    0     0                    -19222.00000 -15636.387  18.7%     -    0s
#      0     0 -15642.000    0   31 -19222.000 -15642.000  18.6%     -    0s
#      0     0 -15642.000    0   31 -19222.000 -15642.000  18.6%     -    0s
# H    0     0                    -16986.00000 -15642.000  7.91%     -    0s
#      0     0 -15646.613    0   16 -16986.000 -15646.613  7.89%     -    0s
#      0     0 -15646.613    0   12 -16986.000 -15646.613  7.89%     -    0s
#      0     0 -15646.613    0   24 -16986.000 -15646.613  7.89%     -    0s
#      0     0 -15646.613    0   26 -16986.000 -15646.613  7.89%     -    0s
#      0     0 -15646.613    0   28 -16986.000 -15646.613  7.89%     -    0s
#      0     0 -15646.799    0   33 -16986.000 -15646.799  7.88%     -    0s
#      0     0 -15646.799    0   33 -16986.000 -15646.799  7.88%     -    0s
#      0     0 -15646.862    0   24 -16986.000 -15646.862  7.88%     -    0s
#      0     0 -15646.889    0   29 -16986.000 -15646.889  7.88%     -    0s
#      0     0 -15744.014    0   22 -16986.000 -15744.014  7.31%     -    0s
#      0     0 -15785.000    0   20 -16986.000 -15785.000  7.07%     -    0s
#      0     0 -15785.000    0   12 -16986.000 -15785.000  7.07%     -    0s
#      0     0 -15785.000    0   12 -16986.000 -15785.000  7.07%     -    0s
#      0     2 -15927.264    0    8 -16986.000 -15927.264  6.23%     -    0s
# H   77    73                    -16871.00000 -16158.200  4.23%   3.0    0s
# *  199   106              10    -16849.00000 -16214.645  3.76%   3.1    0s
# *  386   146              27    -16834.00000 -16353.800  2.85%   3.5    0s
# H  404   146                    -16735.00000 -16353.800  2.28%   3.5    0s
# H  569   118                    -16674.00000 -16456.000  1.31%   3.9    0s
#
# Cutting planes:
#   Learned: 22
#   Gomory: 11
#   Implied bound: 15
#   MIR: 21
#   Inf proof: 2
#   RLT: 1
#   Relax-and-lift: 9
#
# Explored 782 nodes (3350 simplex iterations) in 0.45 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: -16674 -16735 -16834 ... -20819
# No other solutions better than -16674
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.667400000000e+04, best bound -1.667400000000e+04, gap 0.0000%
#
# ------------------------------------------------------------------------------
#
# Total cost 16674
#
# ------------------------------------------------------------------------------

# %% [markdown]
# ## **Ex1_Q3 ->** From network 1, suppose that you can install one hub in one of the nodes \[6,11,14\] with the following features:
#     a.	If the hub is installed in node k, the cost of a link from node k to any other node is zero;
#     b.	The hub can accept up to 6 connections.

# %% [markdown]
# ### Hub in node 6

# %%
hub = 6
G1 = G.copy()

# %%
#set to 0 all cost of arcs connected to the hub
for i,j in G1.edges(hub):
    G1[i][j]['cost'] = 0
        
D1 = G1.to_directed()

# %%
pcst = gb.Model()
pcst.ModelSense = gb.GRB.MAXIMIZE

# Variables definition

x1 = pcst.addVars(D1.edges(), vtype=gb.GRB.BINARY, \
                 obj = [- D1[i][j]['cost'] for i,j in D1.edges()], \
                 name = 'x1')

# here we avoid to set the `obj` parameter because there is no profit attribute
y1 = pcst.addVars (G1.nodes(), vtype = gb.GRB.BINARY, \
                  name = 'y1')

u1 = pcst.addVars (G1.nodes(), vtype = gb.GRB.CONTINUOUS, 
                  lb = 0.0, ub = G1.number_of_nodes(),\
                 name = 'u1')

# %%
# Constraints 

# Root is in the solution
pcst.addConstr(y1[root] == 1, name = 'Fix')

pcst.update()

# Each node has exactly one incoming arc

pcst.addConstrs((x1.sum('*',j) == y1[j] for j in G1.nodes() if j != root), name='Node')

# Precedence constraints (MTZ constraints)

pcst.addConstrs(((G1.number_of_nodes() +  1) * x1[i,j] + u1[i] - u1[j] <= G1.number_of_nodes() for i,j in D1.edges()), name = 'MTZ')

# Connectivity constraints

pcst.addConstrs((x1[j,k] <= y1[j] for j in G1.nodes() \
                 if j != root for k in D1.neighbors(j)), name = 'Connect')

## connect all nodes constraint
customers = {i:G1.nodes[i]["customer"] for i in G1.nodes()}
n_customers = sum([G1.nodes[i]["customer"] for i in G1.nodes()])

pcst.addConstr(y1.prod(customers) >= n_customers, name = 'minCustomers')

pcst.update() 
pcst.write('pcst.lp')

# %% [markdown]
# #### we set the max number of hub's connection, so the hub degree constraint

# %%
pcst.addConstr(x1.sum(hub, '*') + x1.sum('*', hub) <= 6, name="hubeDegree")
pcst.update()
pcst.write('mst.lp')

# %%
pcst.optimize()

totalcost = 0

for i,j in D1.edges():
        if x1[i,j].x > 0.1:
            totalcost += D1[i][j]['cost']
            
print("\n------------------------------------------------------------------------------\n")
print ("Total cost for puuting an hub in", hub, "is" , totalcost)
print("\n------------------------------------------------------------------------------\n")

# Draw the solution 
DrawSol(D1,x1)
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1743 rows, 930 columns and 5251 nonzeros
# Model fingerprint: 0x109783b4
# Variable types: 30 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+02, 5e+03]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 3e+05]
# Presolve removed 872 rows and 60 columns
# Presolve time: 0.01s
# Presolved: 871 rows, 870 columns, 3363 nonzeros
# Variable types: 29 continuous, 841 integer (841 binary)
# Found heuristic solution: objective -68501.00000
#
# Root relaxation: objective -9.618774e+03, 103 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9618.7742    0   12 -68501.000 -9618.7742  86.0%     -    0s
# H    0     0                    -21625.00000 -9618.7742  55.5%     -    0s
# H    0     0                    -20412.00000 -9618.7742  52.9%     -    0s
#      0     0 -10645.355    0   25 -20412.000 -10645.355  47.8%     -    0s
# H    0     0                    -20073.00000 -10645.355  47.0%     -    0s
# H    0     0                    -11721.00000 -10645.355  9.18%     -    0s
#      0     0 -10714.000    0   33 -11721.000 -10714.000  8.59%     -    0s
#      0     0 -10714.000    0   32 -11721.000 -10714.000  8.59%     -    0s
#      0     0 -10714.000    0   16 -11721.000 -10714.000  8.59%     -    0s
#      0     0 -10714.000    0   12 -11721.000 -10714.000  8.59%     -    0s
#      0     0 -10714.000    0   22 -11721.000 -10714.000  8.59%     -    0s
#      0     0 -10714.000    0   28 -11721.000 -10714.000  8.59%     -    0s
#      0     0 -10714.000    0   28 -11721.000 -10714.000  8.59%     -    0s
# H    0     0                    -11584.00000 -10714.000  7.51%     -    0s
#      0     0 -10714.000    0   28 -11584.000 -10714.000  7.51%     -    0s
#      0     0 -10714.000    0   28 -11584.000 -10714.000  7.51%     -    0s
#      0     0 -10714.000    0   28 -11584.000 -10714.000  7.51%     -    0s
#      0     0 -10714.000    0   28 -11584.000 -10714.000  7.51%     -    0s
#      0     0 -10714.000    0   16 -11584.000 -10714.000  7.51%     -    0s
#      0     0 -10714.000    0   18 -11584.000 -10714.000  7.51%     -    0s
#      0     0 -10714.000    0   14 -11584.000 -10714.000  7.51%     -    0s
#      0     0 -10714.000    0   18 -11584.000 -10714.000  7.51%     -    0s
#      0     0 -10714.000    0   16 -11584.000 -10714.000  7.51%     -    0s
#      0     0 -
seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: -11584 -11721 -20073 ... -68501
# No other solutions better than -11584
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.158400000000e+04, best bound -1.158400000000e+04, gap 0.0000%
#
# ------------------------------------------------------------------------------
#
# Total cost for puuting an hub in 6 is 11584
#
# ------------------------------------------------------------------------------

# %% [markdown]
# ### Hub in node 11

# %%
hub = 11
G1 = G.copy()

# %%
#set to 0 all cost of arcs connected to the hub
for i,j in G1.edges(hub):
    G1[i][j]['cost'] = 0
        
D1 = G1.to_directed()

# %%
pcst = gb.Model()
pcst.ModelSense = gb.GRB.MAXIMIZE

# Variables definition

x2 = pcst.addVars(D1.edges(), vtype=gb.GRB.BINARY, \
                 obj = [- D1[i][j]['cost'] for i,j in D1.edges()], \
                 name = 'x2')

# here we avoid to set the `obj` parameter because there is no profit attribute
y2 = pcst.addVars (G1.nodes(), vtype = gb.GRB.BINARY, \
                  name = 'y2')

u2 = pcst.addVars (G1.nodes(), vtype = gb.GRB.CONTINUOUS, 
                  lb = 0.0, ub = G1.number_of_nodes(),\
                 name = 'u2')

# %%
# Constraints 

# Root is in the solution
pcst.addConstr(y2[root] == 1, name = 'Fix')

pcst.update()

# Each node has exactly one incoming arc

pcst.addConstrs((x2.sum('*',j) == y2[j] for j in G1.nodes() if j != root), name='Node')

# Precedence constraints (MTZ constraints)

pcst.addConstrs(((G1.number_of_nodes() +  1) * x2[i,j] + u2[i] - u2[j] <= G1.number_of_nodes() for i,j in D1.edges()), name = 'MTZ')

# Connectivity constraints

pcst.addConstrs((x2[j,k] <= y2[j] for j in G1.nodes() \
                 if j != root for k in D1.neighbors(j)), name = 'Connect')

## connect all nodes constraint
customers = {i:G1.nodes[i]["customer"] for i in G1.nodes()}
n_customers = sum([G1.nodes[i]["customer"] for i in G1.nodes()])

pcst.addConstr(y2.prod(customers) >= n_customers, name = 'minCustomers')

pcst.update() 
pcst.write('pcst.lp')

# %% [markdown]
# #### we set the max number of hub's connection, so the hub degree constraint

# %%
pcst.addConstr(x2.sum(hub, '*') + x2.sum('*', hub) <= 6, name="hubeDegree")
pcst.update()
pcst.write('mst.lp')

# %%
pcst.optimize()

totalcost = 0

for i,j in D1.edges():
        if x2[i,j].x > 0.1:
            totalcost += D1[i][j]['cost']
            
print("\n------------------------------------------------------------------------------\n")
print ("Total cost for puuting an hub in", hub, "is" , totalcost)
print("\n------------------------------------------------------------------------------\n")

# Draw the solution 
DrawSol(D1,x2)
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1743 rows, 930 columns and 5251 nonzeros
# Model fingerprint: 0x81c57028
# Variable types: 30 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+02, 5e+03]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 3e+05]
# Presolve removed 872 rows and 60 columns
# Presolve time: 0.01s
# Presolved: 871 rows, 870 columns, 3363 nonzeros
# Variable types: 29 continuous, 841 integer (841 binary)
# Found heuristic solution: objective -68013.00000
#
# Root relaxation: objective -9.921548e+03, 101 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9921.5484    0   12 -68013.000 -9921.5484  85.4%     -    0s
# H    0     0                    -21461.00000 -9921.5484  53.8%     -    0s
# H    0     0                    -15767.00000 -9921.5484  37.1%     -    0s
#      0     0 -10782.355    0   23 -15767.000 -10782.355  31.6%     -    0s
# H    0     0                    -14467.00000 -10782.355  25.5%     -    0s
# H    0     0                    -12492.00000 -10782.355  13.7%     -    0s
#      0     0 -10851.000    0   32 -12492.000 -10851.000  13.1%     -    0s
#      0     0 -10851.000    0   32 -12492.000 -10851.000  13.1%     -    0s
#      0     0 -10851.000    0   14 -12492.000 -10851.000  13.1%     -    0s
#      0     0 -10851.000    0   12 -12492.000 -10851.000  13.1%     -    0s
#      0     0 -10851.000    0   22 -12492.000 -10851.000  13.1%     -    0s
# H    0     0                    -11858.00000 -10851.000  8.49%     -    0s
#      0     0 -10851.000    0   18 -11858.000 -10851.000  8.49%     -    0s
#      0     0 -10851.000    0   18 -11858.000 -10851.000  8.49%     -    0s
#      0     0 -10851.000    0   16 -11858.000 -10851.000  8.49%     -    0s
#      0     0 -10851.000    0   12 -11858.000 -10851.000  8.49%     -    0s
#      0     0 -10851.000    0   22 -11858.000 -10851.000  8.49%     -    0s
#      0     0 -10851.000    0   18 -11858.000 -10851.000  8.49%     -    0s
#      0     0 -10851.000    0   18 -11858.000 -10851.000  8.49%     -    0s
#      0     0 -10853.781    0   14 -11858.000 -10853.781  8.47%     -    0s
#      0     0 -10859.348    0   19 -11858.000 -10859.348  8.42%     -    0s
#      0     0 -10859.371    0   19 -11858.000 -10859.371  8.42%     -    0s
#      0     0 -10933.624    0   19 -11858.000 -10933.624  7.80%     -    0s
#      0     0 -10933.624    0   19 -11858.000 -10933.624  7.80%     -    0s
#      0     0 -10986.667    0   17 -11858.000 -10986.667  7.35%     -    0s
# H    0     0                    -11721.00000 -10986.667  6.27%     -    0s
#      0     0 -10986.667    0   17 -11721.000 -10986.667  6.27%     -    0s
#      0     0 -10986.667    0   13 -11721.000 -10986.667  6.27%     -    0s
#      0     0 -10986.667    0   13 -11721.000 -10986.667  6.27%     -    0s
#      0     0 -11104.351    0   14 -11721.000 -11104.351  5.26%     -    0s
#      0     0 -11104.351    0   20 -11721.000 -11104.351  5.26%     -    0s
#      0     0 -11104.351    0   33 -11721.000 -11104.351  5.26%     -    0s
#      0     0 -11104.351    0   33 -11721.000 -11104.351  5.26%     -    0s
#      0     0 -11104.351    0   29 -11721.000 -11104.351  5.26%     -    0s
#      0     0 -11104.351    0   29 -11721.000 -11104.351  5.26%     -    0s
#      0     0 -11104.351    0   29 -11721.000 -11104.351  5.26%     -    0s
#      0     0 -11104.351    0   13 -11721.000 -11104.351  5.26%     -    0s
#      0     0 -11104.351    0   13 -11721.000 -11104.351  5.26%     -    0s
#      0     0 -11104.351    0   13 -11721.000 -11104.351  5.26%     -    0s
#      0     2 -11141.451    0   13 -11721.000 -11141.451  4.94%     -    0s
#
# Cutting planes:
#   Learned: 18
#   Gomory: 7
#   Implied bound: 5
#   MIR: 15
#   Inf proof: 2
#   Relax-and-lift: 1
#
# Explored 290 nodes (2163 simplex iterations) in 0.45 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: -11721 -11858 -12492 ... -68013
# No other solutions better than -11721
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.172100000000e+04, best bound -1.172100000000e+04, gap 0.0000%
#
# ------------------------------------------------------------------------------
#
# Total cost for puuting an hub in 11 is 11721
#
# ------------------------------------------------------------------------------

# %% [markdown]
# ### Hub in node 14

# %%
hub = 14
G1 = G.copy()

# %%
#set to 0 all cost of arcs connected to the hub
for i,j in G1.edges(hub):
    G1[i][j]['cost'] = 0
        
D1 = G1.to_directed()

# %%
pcst = gb.Model()
pcst.ModelSense = gb.GRB.MAXIMIZE

# Variables definition

x3 = pcst.addVars(D1.edges(), vtype=gb.GRB.BINARY, \
                 obj = [- D1[i][j]['cost'] for i,j in D1.edges()], \
                 name = 'x3')

# here we avoid to set the `obj` parameter because there is no profit attribute
y3 = pcst.addVars (G1.nodes(), vtype = gb.GRB.BINARY, \
                  name = 'y3')

u3 = pcst.addVars (G1.nodes(), vtype = gb.GRB.CONTINUOUS, 
                  lb = 0.0, ub = G1.number_of_nodes(),\
                 name = 'u3')

# %%
# Constraints 

# Root is in the solution
pcst.addConstr(y3[root] == 1, name = 'Fix')

pcst.update()

# Each node has exactly one incoming arc

pcst.addConstrs((x3.sum('*',j) == y3[j] for j in G1.nodes() if j != root), name='Node')

# Precedence constraints (MTZ constraints)

pcst.addConstrs(((G1.number_of_nodes() +  1) * x3[i,j] + u3[i] - u3[j] <= G1.number_of_nodes() for i,j in D1.edges()), name = 'MTZ')

# Connectivity constraints

pcst.addConstrs((x3[j,k] <= y3[j] for j in G1.nodes() \
                 if j != root for k in D1.neighbors(j)), name = 'Connect')

## connect all nodes constraint
customers = {i:G1.nodes[i]["customer"] for i in G1.nodes()}
n_customers = sum([G1.nodes[i]["customer"] for i in G1.nodes()])

pcst.addConstr(y3.prod(customers) >= n_customers, name = 'minCustomers')

pcst.update() 
pcst.write('pcst.lp')

# %% [markdown]
# #### we set the max number of hub's connection, so the hub degree constraint

# %%
pcst.addConstr(x3.sum(hub, '*') + x3.sum('*', hub) <= 6, name="hubeDegree")
pcst.update()
pcst.write('mst.lp')

# %%
pcst.optimize()

totalcost = 0

for i,j in D1.edges():
        if x3[i,j].x > 0.1:
            totalcost += D1[i][j]['cost']
            
print("\n------------------------------------------------------------------------------\n")
print ("Total cost for putting an hub in", hub, "is" , totalcost)
print("\n------------------------------------------------------------------------------\n")

# Draw the solution 
DrawSol(D1,x3)
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1743 rows, 930 columns and 5251 nonzeros
# Model fingerprint: 0x911e0c2b
# Variable types: 30 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+02, 5e+03]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 3e+05]
# Presolve removed 872 rows and 60 columns
# Presolve time: 0.01s
# Presolved: 871 rows, 870 columns, 3363 nonzeros
# Variable types: 29 continuous, 841 integer (841 binary)
# Found heuristic solution: objective -68161.00000
#
# Root relaxation: objective -9.589419e+03, 99 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9589.4194    0   12 -68161.000 -9589.4194  85.9%     -    0s
# H    0     0                    -21446.00000 -9589.4194  55.3%     -    0s
# H    0     0                    -16089.00000 -9589.4194  40.4%     -    0s
#      0     0 -10767.355    0   23 -16089.000 -10767.355  33.1%     -    0s
# H    0     0                    -14789.00000 -10767.355  27.2%     -    0s
# H    0     0                    -11843.00000 -10767.355  9.08%     -    0s
#      0     0 -10836.000    0   32 -11843.000 -10836.000  8.50%     -    0s
#      0     0 -10836.000    0   32 -11843.000 -10836.000  8.50%     -    0s
#      0     0 -10836.000    0   14 -11843.000 -10836.000  8.50%     -    0s
#      0     0 -10836.000    0   12 -11843.000 -10836.000  8.50%     -    0s
#      0     0 -10836.000    0   24 -11843.000 -10836.000  8.50%     -    0s
#      0     0 -10836.000    0   30 -11843.000 -10836.000  8.50%     -    0s
#      0     0 -10836.000    0   30 -11843.000 -10836.000  8.50%     -    0s
# H    0     0                    -11706.00000 -10836.000  7.43%     -    0s
#      0     0 -10836.000    0   30 -11706.000 -10836.000  7.43%     -    0s
#      0     0 -10836.000    0   30 -11706.000 -10836.000  7.43%     -    0s
#      0     0 -10836.000    0   26 -11706.000 -10836.000  7.43%     -    0s
#      0     0 -10837.394    0   31 -11706.000 -10837.394  7.42%     -    0s
#      0     0 -10837.394    0   31 -11706.000 -10837.394  7.42%     -    0s
#      0     0 -10868.262    0   20 -11706.000 -10868.262  7.16%     -    0s
#      0     0 -10868.359    0   20 -11706.000 -10868.359  7.16%     -    0s
#      0     0 -10923.126    0   20 -11706.000 -10923.126  6.69%     -    0s
#      0     0 -10969.081    0   18 -11706.000 -10969.081  6.30%     -    0s
#      0     0 -10971.218    0   23 -11706.000 -10971.218  6.28%     -    0s
#      0     0 -11310.075    0   14 -11706.000 -11310.075  3.38%     -    0s
#      0     0 -11331.500    0   18 -11706.000 -11331.500  3.20%     -    0s
#      0     0 -11331.500    0   18 -11706.000 -11331.500  3.20%     -    0s
#      0     0 -11331.500    0   18 -11706.000 -11331.500  3.20%     -    0s
#      0     0 -11331.500    0   12 -11706.000 -11331.500  3.20%     -    0s
#      0     0 -11331.500    0   24 -11706.000 -11331.500  3.20%     -    0s
#      0     0 -11331.500    0   22 -11706.000 -11331.500  3.20%     -    0s
#      0     0 -11331.500    0   22 -11706.000 -11331.500  3.20%     -    0s
#      0     0 -11333.361    0   18 -11706.000 -11333.361  3.18%     -    0s
#      0     0 -11333.361    0   18 -11706.000 -11333.361  3.18%     -    0s
#      0     0 -11374.900    0   15 -11706.000 -11374.900  2.83%     -    0s
#      0     0 -11404.000    0   18 -11706.000 -11404.000  2.58%     -    0s
#      0     0 -11404.000    0   18 -11706.000 -11404.000  2.58%     -    0s
#      0     0 -11431.000    0   20 -11706.000 -11431.000  2.35%     -    0s
#      0     0 -11431.000    0   20 -11706.000 -11431.000  2.35%     -    0s
#      0     0 -11482.000    0   18 -11706.000 -11482.000  1.91%     -    0s
#      0     0 -11482.000    0   18 -11706.000 -11482.000  1.91%     -    0s
#      0     0 -11482.000    0   18 -11706.000 -11482.000  1.91%     -    0s
#      0     0 -11482.000    0   14 -11706.000 -11482.000  1.91%     -    0s
#      0     0 -11482.000    0   14 -11706.000 -11482.000  1.91%     -    0s
#      0     0 -11482.000    0   14 -11706.000 -11482.000  1.91%     -    0s
#      0     0 -11482.000    0   14 -11706.000 -11482.000  1.91%     -    0s
#      0     0 -11493.027    0   11 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   20 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   24 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   24 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   20 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   26 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   26 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   22 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   22 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   22 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   22 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   14 -11706.000 -11493.027  1.82%     -    0s
#      0     0 -11493.027    0   14 -11706.000 -11493.027  1.82%     -    0s
#      0     2 -11520.500    0   14 -11706.000 -11520.500  1.58%     -    0s
#
# Cutting planes:
#   Learned: 14
#   Gomory: 6
#   Implied bound: 3
#   MIR: 20
#   Inf proof: 1
#   RLT: 2
#   Relax-and-lift: 6
#
# Explored 96 nodes (1474 simplex iterations) in 0.39 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: -11706 -11843 -14789 ... -68161
# No other solutions better than -11706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.170600000000e+04, best bound -1.170600000000e+04, gap 0.0000%
#
# ------------------------------------------------------------------------------
#
# Total cost for putting an hub in 14 is 11706
#
# ------------------------------------------------------------------------------

# %% [markdown]
# **Conclusions**
# - Total cost for puuting an hub in node 14 is 11706
# - Total cost for puuting an hub in node 11 is 11721
# - Total cost for putting an hub in node 6  is 11584
